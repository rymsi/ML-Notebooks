# %%
import tensorflow as tf
tf.reset_default_graph()

n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
training = tf.placeholder_with_default(False, shape=(), name="training")

hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1")
bn1 = tf.layers.batch_normalization(hidden1, training=training, momentum=0.9)
bn1_act = tf.nn.elu(bn1)

hidden2 = tf.layers.dense(bn1_act, n_hidden2, name="hidden2")
bn2 = tf.layers.batch_normalization(hidden2, training=training, momentum=0.9)
bn2_act = tf.nn.elu(bn2)

logits_before_bn = tf.layers.dense(bn2_act, n_outputs, name="outputs")
logits = tf.layers.batch_normalization(logits_before_bn, training=training, momentum=0.9)

# %%
y = tf.placeholder(tf.int32, shape=(None), name="y")
he_init = tf.variance_scaling_initializer()

# %%
learning_rate = 0.01
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()

# %%
n_epochs = 5
batch_size = 200

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
import numpy as np
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run([training_op, extra_update_ops], feed_dict={training:True, X:X_batch, y:y_batch})
        accuracy_val = accuracy.eval(feed_dict={X:X_valid, y:y_valid})
        print(epoch, "Validation accuracy:", accuracy_val)
    saver = tf.train.Saver()
    save_path = saver.save(sess, "./mnist_nn_ch11.ckpt")
# Out:
# 0 Validation accuracy: 0.8834
# 1 Validation accuracy: 0.906
# 2 Validation accuracy: 0.92
# 3 Validation accuracy: 0.9304
# 4 Validation accuracy: 0.9368

# %%
tf.reset_default_graph()

# %%
saver = tf.train.import_meta_graph("./mnist_nn_ch11.ckpt.meta")
for op in tf.get_default_graph().get_operations():
    print(op.name)
# Out:
# X
# training/input
# training
# hidden1/kernel/Initializer/random_uniform/shape
# hidden1/kernel/Initializer/random_uniform/min
# hidden1/kernel/Initializer/random_uniform/max
# hidden1/kernel/Initializer/random_uniform/RandomUniform
# hidden1/kernel/Initializer/random_uniform/sub
# hidden1/kernel/Initializer/random_uniform/mul
# hidden1/kernel/Initializer/random_uniform
# hidden1/kernel
# hidden1/kernel/Assign
# hidden1/kernel/read
# hidden1/bias/Initializer/zeros
# hidden1/bias
# hidden1/bias/Assign
# hidden1/bias/read
# hidden1/MatMul
# hidden1/BiasAdd
# batch_normalization/gamma/Initializer/ones
# batch_normalization/gamma
# batch_normalization/gamma/Assign
# batch_normalization/gamma/read
# batch_normalization/beta/Initializer/zeros
# batch_normalization/beta
# batch_normalization/beta/Assign
# batch_normalization/beta/read
# batch_normalization/moving_mean/Initializer/zeros
# batch_normalization/moving_mean
# batch_normalization/moving_mean/Assign
# batch_normalization/moving_mean/read
# batch_normalization/moving_variance/Initializer/ones
# batch_normalization/moving_variance
# batch_normalization/moving_variance/Assign
# batch_normalization/moving_variance/read
# batch_normalization/moments/mean/reduction_indices
# batch_normalization/moments/mean
# batch_normalization/moments/StopGradient
# batch_normalization/moments/SquaredDifference
# batch_normalization/moments/variance/reduction_indices
# batch_normalization/moments/variance
# batch_normalization/moments/Squeeze
# batch_normalization/moments/Squeeze_1
# batch_normalization/cond/Switch
# batch_normalization/cond/switch_t
# batch_normalization/cond/switch_f
# batch_normalization/cond/pred_id
# batch_normalization/cond/Switch_1
# batch_normalization/cond/Switch_2
# batch_normalization/cond/Merge
# batch_normalization/cond_1/Switch
# batch_normalization/cond_1/switch_t
# batch_normalization/cond_1/switch_f
# batch_normalization/cond_1/pred_id
# batch_normalization/cond_1/Switch_1
# batch_normalization/cond_1/Switch_2
# batch_normalization/cond_1/Merge
# batch_normalization/cond_2/Switch
# batch_normalization/cond_2/switch_t
# batch_normalization/cond_2/switch_f
# batch_normalization/cond_2/pred_id
# batch_normalization/cond_2/AssignMovingAvg/decay
# batch_normalization/cond_2/AssignMovingAvg/sub/Switch
# batch_normalization/cond_2/AssignMovingAvg/sub/Switch_1
# batch_normalization/cond_2/AssignMovingAvg/sub
# batch_normalization/cond_2/AssignMovingAvg/mul
# batch_normalization/cond_2/AssignMovingAvg/Switch
# batch_normalization/cond_2/AssignMovingAvg
# batch_normalization/cond_2/Switch_1
# batch_normalization/cond_2/Merge
# batch_normalization/cond_3/Switch
# batch_normalization/cond_3/switch_t
# batch_normalization/cond_3/switch_f
# batch_normalization/cond_3/pred_id
# batch_normalization/cond_3/AssignMovingAvg/decay
# batch_normalization/cond_3/AssignMovingAvg/sub/Switch
# batch_normalization/cond_3/AssignMovingAvg/sub/Switch_1
# batch_normalization/cond_3/AssignMovingAvg/sub
# batch_normalization/cond_3/AssignMovingAvg/mul
# batch_normalization/cond_3/AssignMovingAvg/Switch
# batch_normalization/cond_3/AssignMovingAvg
# batch_normalization/cond_3/Switch_1
# batch_normalization/cond_3/Merge
# batch_normalization/batchnorm/add/y
# batch_normalization/batchnorm/add
# batch_normalization/batchnorm/Rsqrt
# batch_normalization/batchnorm/mul
# batch_normalization/batchnorm/mul_1
# batch_normalization/batchnorm/mul_2
# batch_normalization/batchnorm/sub
# batch_normalization/batchnorm/add_1
# Elu
# hidden2/kernel/Initializer/random_uniform/shape
# hidden2/kernel/Initializer/random_uniform/min
# hidden2/kernel/Initializer/random_uniform/max
# hidden2/kernel/Initializer/random_uniform/RandomUniform
# hidden2/kernel/Initializer/random_uniform/sub
# hidden2/kernel/Initializer/random_uniform/mul
# hidden2/kernel/Initializer/random_uniform
# hidden2/kernel
# hidden2/kernel/Assign
# hidden2/kernel/read
# hidden2/bias/Initializer/zeros
# hidden2/bias
# hidden2/bias/Assign
# hidden2/bias/read
# hidden2/MatMul
# hidden2/BiasAdd
# batch_normalization_1/gamma/Initializer/ones
# batch_normalization_1/gamma
# batch_normalization_1/gamma/Assign
# batch_normalization_1/gamma/read
# batch_normalization_1/beta/Initializer/zeros
# batch_normalization_1/beta
# batch_normalization_1/beta/Assign
# batch_normalization_1/beta/read
# batch_normalization_1/moving_mean/Initializer/zeros
# batch_normalization_1/moving_mean
# batch_normalization_1/moving_mean/Assign
# batch_normalization_1/moving_mean/read
# batch_normalization_1/moving_variance/Initializer/ones
# batch_normalization_1/moving_variance
# batch_normalization_1/moving_variance/Assign
# batch_normalization_1/moving_variance/read
# batch_normalization_1/moments/mean/reduction_indices
# batch_normalization_1/moments/mean
# batch_normalization_1/moments/StopGradient
# batch_normalization_1/moments/SquaredDifference
# batch_normalization_1/moments/variance/reduction_indices
# batch_normalization_1/moments/variance
# batch_normalization_1/moments/Squeeze
# batch_normalization_1/moments/Squeeze_1
# batch_normalization_1/cond/Switch
# batch_normalization_1/cond/switch_t
# batch_normalization_1/cond/switch_f
# batch_normalization_1/cond/pred_id
# batch_normalization_1/cond/Switch_1
# batch_normalization_1/cond/Switch_2
# batch_normalization_1/cond/Merge
# batch_normalization_1/cond_1/Switch
# batch_normalization_1/cond_1/switch_t
# batch_normalization_1/cond_1/switch_f
# batch_normalization_1/cond_1/pred_id
# batch_normalization_1/cond_1/Switch_1
# batch_normalization_1/cond_1/Switch_2
# batch_normalization_1/cond_1/Merge
# batch_normalization_1/cond_2/Switch
# batch_normalization_1/cond_2/switch_t
# batch_normalization_1/cond_2/switch_f
# batch_normalization_1/cond_2/pred_id
# batch_normalization_1/cond_2/AssignMovingAvg/decay
# batch_normalization_1/cond_2/AssignMovingAvg/sub/Switch
# batch_normalization_1/cond_2/AssignMovingAvg/sub/Switch_1
# batch_normalization_1/cond_2/AssignMovingAvg/sub
# batch_normalization_1/cond_2/AssignMovingAvg/mul
# batch_normalization_1/cond_2/AssignMovingAvg/Switch
# batch_normalization_1/cond_2/AssignMovingAvg
# batch_normalization_1/cond_2/Switch_1
# batch_normalization_1/cond_2/Merge
# batch_normalization_1/cond_3/Switch
# batch_normalization_1/cond_3/switch_t
# batch_normalization_1/cond_3/switch_f
# batch_normalization_1/cond_3/pred_id
# batch_normalization_1/cond_3/AssignMovingAvg/decay
# batch_normalization_1/cond_3/AssignMovingAvg/sub/Switch
# batch_normalization_1/cond_3/AssignMovingAvg/sub/Switch_1
# batch_normalization_1/cond_3/AssignMovingAvg/sub
# batch_normalization_1/cond_3/AssignMovingAvg/mul
# batch_normalization_1/cond_3/AssignMovingAvg/Switch
# batch_normalization_1/cond_3/AssignMovingAvg
# batch_normalization_1/cond_3/Switch_1
# batch_normalization_1/cond_3/Merge
# batch_normalization_1/batchnorm/add/y
# batch_normalization_1/batchnorm/add
# batch_normalization_1/batchnorm/Rsqrt
# batch_normalization_1/batchnorm/mul
# batch_normalization_1/batchnorm/mul_1
# batch_normalization_1/batchnorm/mul_2
# batch_normalization_1/batchnorm/sub
# batch_normalization_1/batchnorm/add_1
# Elu_1
# outputs/kernel/Initializer/random_uniform/shape
# outputs/kernel/Initializer/random_uniform/min
# outputs/kernel/Initializer/random_uniform/max
# outputs/kernel/Initializer/random_uniform/RandomUniform
# outputs/kernel/Initializer/random_uniform/sub
# outputs/kernel/Initializer/random_uniform/mul
# outputs/kernel/Initializer/random_uniform
# outputs/kernel
# outputs/kernel/Assign
# outputs/kernel/read
# outputs/bias/Initializer/zeros
# outputs/bias
# outputs/bias/Assign
# outputs/bias/read
# outputs/MatMul
# outputs/BiasAdd
# batch_normalization_2/gamma/Initializer/ones
# batch_normalization_2/gamma
# batch_normalization_2/gamma/Assign
# batch_normalization_2/gamma/read
# batch_normalization_2/beta/Initializer/zeros
# batch_normalization_2/beta
# batch_normalization_2/beta/Assign
# batch_normalization_2/beta/read
# batch_normalization_2/moving_mean/Initializer/zeros
# batch_normalization_2/moving_mean
# batch_normalization_2/moving_mean/Assign
# batch_normalization_2/moving_mean/read
# batch_normalization_2/moving_variance/Initializer/ones
# batch_normalization_2/moving_variance
# batch_normalization_2/moving_variance/Assign
# batch_normalization_2/moving_variance/read
# batch_normalization_2/moments/mean/reduction_indices
# batch_normalization_2/moments/mean
# batch_normalization_2/moments/StopGradient
# batch_normalization_2/moments/SquaredDifference
# batch_normalization_2/moments/variance/reduction_indices
# batch_normalization_2/moments/variance
# batch_normalization_2/moments/Squeeze
# batch_normalization_2/moments/Squeeze_1
# batch_normalization_2/cond/Switch
# batch_normalization_2/cond/switch_t
# batch_normalization_2/cond/switch_f
# batch_normalization_2/cond/pred_id
# batch_normalization_2/cond/Switch_1
# batch_normalization_2/cond/Switch_2
# batch_normalization_2/cond/Merge
# batch_normalization_2/cond_1/Switch
# batch_normalization_2/cond_1/switch_t
# batch_normalization_2/cond_1/switch_f
# batch_normalization_2/cond_1/pred_id
# batch_normalization_2/cond_1/Switch_1
# batch_normalization_2/cond_1/Switch_2
# batch_normalization_2/cond_1/Merge
# batch_normalization_2/cond_2/Switch
# batch_normalization_2/cond_2/switch_t
# batch_normalization_2/cond_2/switch_f
# batch_normalization_2/cond_2/pred_id
# batch_normalization_2/cond_2/AssignMovingAvg/decay
# batch_normalization_2/cond_2/AssignMovingAvg/sub/Switch
# batch_normalization_2/cond_2/AssignMovingAvg/sub/Switch_1
# batch_normalization_2/cond_2/AssignMovingAvg/sub
# batch_normalization_2/cond_2/AssignMovingAvg/mul
# batch_normalization_2/cond_2/AssignMovingAvg/Switch
# batch_normalization_2/cond_2/AssignMovingAvg
# batch_normalization_2/cond_2/Switch_1
# batch_normalization_2/cond_2/Merge
# batch_normalization_2/cond_3/Switch
# batch_normalization_2/cond_3/switch_t
# batch_normalization_2/cond_3/switch_f
# batch_normalization_2/cond_3/pred_id
# batch_normalization_2/cond_3/AssignMovingAvg/decay
# batch_normalization_2/cond_3/AssignMovingAvg/sub/Switch
# batch_normalization_2/cond_3/AssignMovingAvg/sub/Switch_1
# batch_normalization_2/cond_3/AssignMovingAvg/sub
# batch_normalization_2/cond_3/AssignMovingAvg/mul
# batch_normalization_2/cond_3/AssignMovingAvg/Switch
# batch_normalization_2/cond_3/AssignMovingAvg
# batch_normalization_2/cond_3/Switch_1
# batch_normalization_2/cond_3/Merge
# batch_normalization_2/batchnorm/add/y
# batch_normalization_2/batchnorm/add
# batch_normalization_2/batchnorm/Rsqrt
# batch_normalization_2/batchnorm/mul
# batch_normalization_2/batchnorm/mul_1
# batch_normalization_2/batchnorm/mul_2
# batch_normalization_2/batchnorm/sub
# batch_normalization_2/batchnorm/add_1
# y
# loss/SparseSoftmaxCrossEntropyWithLogits/Shape
# loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits
# loss/Const
# loss/loss
# train/gradients/Shape
# train/gradients/grad_ys_0
# train/gradients/Fill
# train/gradients/loss/loss_grad/Reshape/shape
# train/gradients/loss/loss_grad/Reshape
# train/gradients/loss/loss_grad/Shape
# train/gradients/loss/loss_grad/Tile
# train/gradients/loss/loss_grad/Shape_1
# train/gradients/loss/loss_grad/Shape_2
# train/gradients/loss/loss_grad/Const
# train/gradients/loss/loss_grad/Prod
# train/gradients/loss/loss_grad/Const_1
# train/gradients/loss/loss_grad/Prod_1
# train/gradients/loss/loss_grad/Maximum/y
# train/gradients/loss/loss_grad/Maximum
# train/gradients/loss/loss_grad/floordiv
# train/gradients/loss/loss_grad/Cast
# train/gradients/loss/loss_grad/truediv
# train/gradients/zeros_like
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Shape
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Shape_1
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Sum
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Reshape
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Sum_1
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/Reshape_1
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Shape
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Shape_1
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Mul
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Sum
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Reshape
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Mul_1
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Sum_1
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/Reshape_1
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/batchnorm/sub_grad/Neg
# train/gradients/batch_normalization_2/batchnorm/sub_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/batchnorm/mul_2_grad/Mul
# train/gradients/batch_normalization_2/batchnorm/mul_2_grad/Mul_1
# train/gradients/batch_normalization_2/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/cond/Merge_grad/cond_grad
# train/gradients/batch_normalization_2/cond/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization_2/cond/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN
# train/gradients/batch_normalization_2/batchnorm/mul_grad/Mul
# train/gradients/batch_normalization_2/batchnorm/mul_grad/Mul_1
# train/gradients/batch_normalization_2/batchnorm/mul_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch
# train/gradients/Identity
# train/gradients/Shape_1
# train/gradients/zeros/Const
# train/gradients/zeros
# train/gradients/batch_normalization_2/cond/Switch_1_grad/cond_grad
# train/gradients/batch_normalization_2/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/batch_normalization_2/moments/Squeeze_grad/Shape
# train/gradients/batch_normalization_2/moments/Squeeze_grad/Reshape
# train/gradients/batch_normalization_2/batchnorm/add_grad/Shape
# train/gradients/batch_normalization_2/batchnorm/add_grad/Shape_1
# train/gradients/batch_normalization_2/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_2/batchnorm/add_grad/Sum
# train/gradients/batch_normalization_2/batchnorm/add_grad/Reshape
# train/gradients/batch_normalization_2/batchnorm/add_grad/Sum_1
# train/gradients/batch_normalization_2/batchnorm/add_grad/Reshape_1
# train/gradients/batch_normalization_2/batchnorm/add_grad/tuple/group_deps
# train/gradients/batch_normalization_2/batchnorm/add_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/batchnorm/add_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/cond_1/Merge_grad/cond_grad
# train/gradients/batch_normalization_2/cond_1/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization_2/cond_1/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/cond_1/Merge_grad/tuple/control_dependency_1
# train/gradients/Switch_1
# train/gradients/Identity_1
# train/gradients/Shape_2
# train/gradients/zeros_1/Const
# train/gradients/zeros_1
# train/gradients/batch_normalization_2/cond_1/Switch_1_grad/cond_grad
# train/gradients/batch_normalization_2/moments/Squeeze_1_grad/Shape
# train/gradients/batch_normalization_2/moments/Squeeze_1_grad/Reshape
# train/gradients/batch_normalization_2/moments/variance_grad/Shape
# train/gradients/batch_normalization_2/moments/variance_grad/Size
# train/gradients/batch_normalization_2/moments/variance_grad/add
# train/gradients/batch_normalization_2/moments/variance_grad/mod
# train/gradients/batch_normalization_2/moments/variance_grad/Shape_1
# train/gradients/batch_normalization_2/moments/variance_grad/range/start
# train/gradients/batch_normalization_2/moments/variance_grad/range/delta
# train/gradients/batch_normalization_2/moments/variance_grad/range
# train/gradients/batch_normalization_2/moments/variance_grad/Fill/value
# train/gradients/batch_normalization_2/moments/variance_grad/Fill
# train/gradients/batch_normalization_2/moments/variance_grad/DynamicStitch
# train/gradients/batch_normalization_2/moments/variance_grad/Maximum/y
# train/gradients/batch_normalization_2/moments/variance_grad/Maximum
# train/gradients/batch_normalization_2/moments/variance_grad/floordiv
# train/gradients/batch_normalization_2/moments/variance_grad/Reshape
# train/gradients/batch_normalization_2/moments/variance_grad/Tile
# train/gradients/batch_normalization_2/moments/variance_grad/Shape_2
# train/gradients/batch_normalization_2/moments/variance_grad/Shape_3
# train/gradients/batch_normalization_2/moments/variance_grad/Const
# train/gradients/batch_normalization_2/moments/variance_grad/Prod
# train/gradients/batch_normalization_2/moments/variance_grad/Const_1
# train/gradients/batch_normalization_2/moments/variance_grad/Prod_1
# train/gradients/batch_normalization_2/moments/variance_grad/Maximum_1/y
# train/gradients/batch_normalization_2/moments/variance_grad/Maximum_1
# train/gradients/batch_normalization_2/moments/variance_grad/floordiv_1
# train/gradients/batch_normalization_2/moments/variance_grad/Cast
# train/gradients/batch_normalization_2/moments/variance_grad/truediv
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Shape
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Shape_1
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/scalar
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/mul
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/sub
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/mul_1
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Sum
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Reshape
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Sum_1
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Reshape_1
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/Neg
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/tuple/group_deps
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/tuple/control_dependency
# train/gradients/batch_normalization_2/moments/SquaredDifference_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_2/moments/mean_grad/Shape
# train/gradients/batch_normalization_2/moments/mean_grad/Size
# train/gradients/batch_normalization_2/moments/mean_grad/add
# train/gradients/batch_normalization_2/moments/mean_grad/mod
# train/gradients/batch_normalization_2/moments/mean_grad/Shape_1
# train/gradients/batch_normalization_2/moments/mean_grad/range/start
# train/gradients/batch_normalization_2/moments/mean_grad/range/delta
# train/gradients/batch_normalization_2/moments/mean_grad/range
# train/gradients/batch_normalization_2/moments/mean_grad/Fill/value
# train/gradients/batch_normalization_2/moments/mean_grad/Fill
# train/gradients/batch_normalization_2/moments/mean_grad/DynamicStitch
# train/gradients/batch_normalization_2/moments/mean_grad/Maximum/y
# train/gradients/batch_normalization_2/moments/mean_grad/Maximum
# train/gradients/batch_normalization_2/moments/mean_grad/floordiv
# train/gradients/batch_normalization_2/moments/mean_grad/Reshape
# train/gradients/batch_normalization_2/moments/mean_grad/Tile
# train/gradients/batch_normalization_2/moments/mean_grad/Shape_2
# train/gradients/batch_normalization_2/moments/mean_grad/Shape_3
# train/gradients/batch_normalization_2/moments/mean_grad/Const
# train/gradients/batch_normalization_2/moments/mean_grad/Prod
# train/gradients/batch_normalization_2/moments/mean_grad/Const_1
# train/gradients/batch_normalization_2/moments/mean_grad/Prod_1
# train/gradients/batch_normalization_2/moments/mean_grad/Maximum_1/y
# train/gradients/batch_normalization_2/moments/mean_grad/Maximum_1
# train/gradients/batch_normalization_2/moments/mean_grad/floordiv_1
# train/gradients/batch_normalization_2/moments/mean_grad/Cast
# train/gradients/batch_normalization_2/moments/mean_grad/truediv
# train/gradients/AddN_1
# train/gradients/outputs/BiasAdd_grad/BiasAddGrad
# train/gradients/outputs/BiasAdd_grad/tuple/group_deps
# train/gradients/outputs/BiasAdd_grad/tuple/control_dependency
# train/gradients/outputs/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/outputs/MatMul_grad/MatMul
# train/gradients/outputs/MatMul_grad/MatMul_1
# train/gradients/outputs/MatMul_grad/tuple/group_deps
# train/gradients/outputs/MatMul_grad/tuple/control_dependency
# train/gradients/outputs/MatMul_grad/tuple/control_dependency_1
# train/gradients/Elu_1_grad/EluGrad
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Shape
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Shape_1
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Sum
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Reshape
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Sum_1
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/Reshape_1
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Shape
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Shape_1
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Mul
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Sum
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Reshape
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Mul_1
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Sum_1
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/Reshape_1
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/batchnorm/sub_grad/Neg
# train/gradients/batch_normalization_1/batchnorm/sub_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/batchnorm/mul_2_grad/Mul
# train/gradients/batch_normalization_1/batchnorm/mul_2_grad/Mul_1
# train/gradients/batch_normalization_1/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/cond/Merge_grad/cond_grad
# train/gradients/batch_normalization_1/cond/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization_1/cond/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN_2
# train/gradients/batch_normalization_1/batchnorm/mul_grad/Mul
# train/gradients/batch_normalization_1/batchnorm/mul_grad/Mul_1
# train/gradients/batch_normalization_1/batchnorm/mul_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch_2
# train/gradients/Identity_2
# train/gradients/Shape_3
# train/gradients/zeros_2/Const
# train/gradients/zeros_2
# train/gradients/batch_normalization_1/cond/Switch_1_grad/cond_grad
# train/gradients/batch_normalization_1/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/batch_normalization_1/moments/Squeeze_grad/Shape
# train/gradients/batch_normalization_1/moments/Squeeze_grad/Reshape
# train/gradients/batch_normalization_1/batchnorm/add_grad/Shape
# train/gradients/batch_normalization_1/batchnorm/add_grad/Shape_1
# train/gradients/batch_normalization_1/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_1/batchnorm/add_grad/Sum
# train/gradients/batch_normalization_1/batchnorm/add_grad/Reshape
# train/gradients/batch_normalization_1/batchnorm/add_grad/Sum_1
# train/gradients/batch_normalization_1/batchnorm/add_grad/Reshape_1
# train/gradients/batch_normalization_1/batchnorm/add_grad/tuple/group_deps
# train/gradients/batch_normalization_1/batchnorm/add_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/batchnorm/add_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/cond_1/Merge_grad/cond_grad
# train/gradients/batch_normalization_1/cond_1/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization_1/cond_1/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/cond_1/Merge_grad/tuple/control_dependency_1
# train/gradients/Switch_3
# train/gradients/Identity_3
# train/gradients/Shape_4
# train/gradients/zeros_3/Const
# train/gradients/zeros_3
# train/gradients/batch_normalization_1/cond_1/Switch_1_grad/cond_grad
# train/gradients/batch_normalization_1/moments/Squeeze_1_grad/Shape
# train/gradients/batch_normalization_1/moments/Squeeze_1_grad/Reshape
# train/gradients/batch_normalization_1/moments/variance_grad/Shape
# train/gradients/batch_normalization_1/moments/variance_grad/Size
# train/gradients/batch_normalization_1/moments/variance_grad/add
# train/gradients/batch_normalization_1/moments/variance_grad/mod
# train/gradients/batch_normalization_1/moments/variance_grad/Shape_1
# train/gradients/batch_normalization_1/moments/variance_grad/range/start
# train/gradients/batch_normalization_1/moments/variance_grad/range/delta
# train/gradients/batch_normalization_1/moments/variance_grad/range
# train/gradients/batch_normalization_1/moments/variance_grad/Fill/value
# train/gradients/batch_normalization_1/moments/variance_grad/Fill
# train/gradients/batch_normalization_1/moments/variance_grad/DynamicStitch
# train/gradients/batch_normalization_1/moments/variance_grad/Maximum/y
# train/gradients/batch_normalization_1/moments/variance_grad/Maximum
# train/gradients/batch_normalization_1/moments/variance_grad/floordiv
# train/gradients/batch_normalization_1/moments/variance_grad/Reshape
# train/gradients/batch_normalization_1/moments/variance_grad/Tile
# train/gradients/batch_normalization_1/moments/variance_grad/Shape_2
# train/gradients/batch_normalization_1/moments/variance_grad/Shape_3
# train/gradients/batch_normalization_1/moments/variance_grad/Const
# train/gradients/batch_normalization_1/moments/variance_grad/Prod
# train/gradients/batch_normalization_1/moments/variance_grad/Const_1
# train/gradients/batch_normalization_1/moments/variance_grad/Prod_1
# train/gradients/batch_normalization_1/moments/variance_grad/Maximum_1/y
# train/gradients/batch_normalization_1/moments/variance_grad/Maximum_1
# train/gradients/batch_normalization_1/moments/variance_grad/floordiv_1
# train/gradients/batch_normalization_1/moments/variance_grad/Cast
# train/gradients/batch_normalization_1/moments/variance_grad/truediv
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Shape
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Shape_1
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/BroadcastGradientArgs
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/scalar
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/mul
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/sub
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/mul_1
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Sum
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Reshape
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Sum_1
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Reshape_1
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/Neg
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/tuple/group_deps
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/tuple/control_dependency
# train/gradients/batch_normalization_1/moments/SquaredDifference_grad/tuple/control_dependency_1
# train/gradients/batch_normalization_1/moments/mean_grad/Shape
# train/gradients/batch_normalization_1/moments/mean_grad/Size
# train/gradients/batch_normalization_1/moments/mean_grad/add
# train/gradients/batch_normalization_1/moments/mean_grad/mod
# train/gradients/batch_normalization_1/moments/mean_grad/Shape_1
# train/gradients/batch_normalization_1/moments/mean_grad/range/start
# train/gradients/batch_normalization_1/moments/mean_grad/range/delta
# train/gradients/batch_normalization_1/moments/mean_grad/range
# train/gradients/batch_normalization_1/moments/mean_grad/Fill/value
# train/gradients/batch_normalization_1/moments/mean_grad/Fill
# train/gradients/batch_normalization_1/moments/mean_grad/DynamicStitch
# train/gradients/batch_normalization_1/moments/mean_grad/Maximum/y
# train/gradients/batch_normalization_1/moments/mean_grad/Maximum
# train/gradients/batch_normalization_1/moments/mean_grad/floordiv
# train/gradients/batch_normalization_1/moments/mean_grad/Reshape
# train/gradients/batch_normalization_1/moments/mean_grad/Tile
# train/gradients/batch_normalization_1/moments/mean_grad/Shape_2
# train/gradients/batch_normalization_1/moments/mean_grad/Shape_3
# train/gradients/batch_normalization_1/moments/mean_grad/Const
# train/gradients/batch_normalization_1/moments/mean_grad/Prod
# train/gradients/batch_normalization_1/moments/mean_grad/Const_1
# train/gradients/batch_normalization_1/moments/mean_grad/Prod_1
# train/gradients/batch_normalization_1/moments/mean_grad/Maximum_1/y
# train/gradients/batch_normalization_1/moments/mean_grad/Maximum_1
# train/gradients/batch_normalization_1/moments/mean_grad/floordiv_1
# train/gradients/batch_normalization_1/moments/mean_grad/Cast
# train/gradients/batch_normalization_1/moments/mean_grad/truediv
# train/gradients/AddN_3
# train/gradients/hidden2/BiasAdd_grad/BiasAddGrad
# train/gradients/hidden2/BiasAdd_grad/tuple/group_deps
# train/gradients/hidden2/BiasAdd_grad/tuple/control_dependency
# train/gradients/hidden2/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/hidden2/MatMul_grad/MatMul
# train/gradients/hidden2/MatMul_grad/MatMul_1
# train/gradients/hidden2/MatMul_grad/tuple/group_deps
# train/gradients/hidden2/MatMul_grad/tuple/control_dependency
# train/gradients/hidden2/MatMul_grad/tuple/control_dependency_1
# train/gradients/Elu_grad/EluGrad
# train/gradients/batch_normalization/batchnorm/add_1_grad/Shape
# train/gradients/batch_normalization/batchnorm/add_1_grad/Shape_1
# train/gradients/batch_normalization/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization/batchnorm/add_1_grad/Sum
# train/gradients/batch_normalization/batchnorm/add_1_grad/Reshape
# train/gradients/batch_normalization/batchnorm/add_1_grad/Sum_1
# train/gradients/batch_normalization/batchnorm/add_1_grad/Reshape_1
# train/gradients/batch_normalization/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Shape
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Shape_1
# train/gradients/batch_normalization/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Mul
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Sum
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Reshape
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Mul_1
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Sum_1
# train/gradients/batch_normalization/batchnorm/mul_1_grad/Reshape_1
# train/gradients/batch_normalization/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/batchnorm/sub_grad/Neg
# train/gradients/batch_normalization/batchnorm/sub_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/batchnorm/mul_2_grad/Mul
# train/gradients/batch_normalization/batchnorm/mul_2_grad/Mul_1
# train/gradients/batch_normalization/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/cond/Merge_grad/cond_grad
# train/gradients/batch_normalization/cond/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization/cond/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization/cond/Merge_grad/tuple/control_dependency_1
# train/gradients/AddN_4
# train/gradients/batch_normalization/batchnorm/mul_grad/Mul
# train/gradients/batch_normalization/batchnorm/mul_grad/Mul_1
# train/gradients/batch_normalization/batchnorm/mul_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/Switch_4
# train/gradients/Identity_4
# train/gradients/Shape_5
# train/gradients/zeros_4/Const
# train/gradients/zeros_4
# train/gradients/batch_normalization/cond/Switch_1_grad/cond_grad
# train/gradients/batch_normalization/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/batch_normalization/moments/Squeeze_grad/Shape
# train/gradients/batch_normalization/moments/Squeeze_grad/Reshape
# train/gradients/batch_normalization/batchnorm/add_grad/Shape
# train/gradients/batch_normalization/batchnorm/add_grad/Shape_1
# train/gradients/batch_normalization/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/batch_normalization/batchnorm/add_grad/Sum
# train/gradients/batch_normalization/batchnorm/add_grad/Reshape
# train/gradients/batch_normalization/batchnorm/add_grad/Sum_1
# train/gradients/batch_normalization/batchnorm/add_grad/Reshape_1
# train/gradients/batch_normalization/batchnorm/add_grad/tuple/group_deps
# train/gradients/batch_normalization/batchnorm/add_grad/tuple/control_dependency
# train/gradients/batch_normalization/batchnorm/add_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/cond_1/Merge_grad/cond_grad
# train/gradients/batch_normalization/cond_1/Merge_grad/tuple/group_deps
# train/gradients/batch_normalization/cond_1/Merge_grad/tuple/control_dependency
# train/gradients/batch_normalization/cond_1/Merge_grad/tuple/control_dependency_1
# train/gradients/Switch_5
# train/gradients/Identity_5
# train/gradients/Shape_6
# train/gradients/zeros_5/Const
# train/gradients/zeros_5
# train/gradients/batch_normalization/cond_1/Switch_1_grad/cond_grad
# train/gradients/batch_normalization/moments/Squeeze_1_grad/Shape
# train/gradients/batch_normalization/moments/Squeeze_1_grad/Reshape
# train/gradients/batch_normalization/moments/variance_grad/Shape
# train/gradients/batch_normalization/moments/variance_grad/Size
# train/gradients/batch_normalization/moments/variance_grad/add
# train/gradients/batch_normalization/moments/variance_grad/mod
# train/gradients/batch_normalization/moments/variance_grad/Shape_1
# train/gradients/batch_normalization/moments/variance_grad/range/start
# train/gradients/batch_normalization/moments/variance_grad/range/delta
# train/gradients/batch_normalization/moments/variance_grad/range
# train/gradients/batch_normalization/moments/variance_grad/Fill/value
# train/gradients/batch_normalization/moments/variance_grad/Fill
# train/gradients/batch_normalization/moments/variance_grad/DynamicStitch
# train/gradients/batch_normalization/moments/variance_grad/Maximum/y
# train/gradients/batch_normalization/moments/variance_grad/Maximum
# train/gradients/batch_normalization/moments/variance_grad/floordiv
# train/gradients/batch_normalization/moments/variance_grad/Reshape
# train/gradients/batch_normalization/moments/variance_grad/Tile
# train/gradients/batch_normalization/moments/variance_grad/Shape_2
# train/gradients/batch_normalization/moments/variance_grad/Shape_3
# train/gradients/batch_normalization/moments/variance_grad/Const
# train/gradients/batch_normalization/moments/variance_grad/Prod
# train/gradients/batch_normalization/moments/variance_grad/Const_1
# train/gradients/batch_normalization/moments/variance_grad/Prod_1
# train/gradients/batch_normalization/moments/variance_grad/Maximum_1/y
# train/gradients/batch_normalization/moments/variance_grad/Maximum_1
# train/gradients/batch_normalization/moments/variance_grad/floordiv_1
# train/gradients/batch_normalization/moments/variance_grad/Cast
# train/gradients/batch_normalization/moments/variance_grad/truediv
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Shape
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Shape_1
# train/gradients/batch_normalization/moments/SquaredDifference_grad/BroadcastGradientArgs
# train/gradients/batch_normalization/moments/SquaredDifference_grad/scalar
# train/gradients/batch_normalization/moments/SquaredDifference_grad/mul
# train/gradients/batch_normalization/moments/SquaredDifference_grad/sub
# train/gradients/batch_normalization/moments/SquaredDifference_grad/mul_1
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Sum
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Reshape
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Sum_1
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Reshape_1
# train/gradients/batch_normalization/moments/SquaredDifference_grad/Neg
# train/gradients/batch_normalization/moments/SquaredDifference_grad/tuple/group_deps
# train/gradients/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency
# train/gradients/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency_1
# train/gradients/batch_normalization/moments/mean_grad/Shape
# train/gradients/batch_normalization/moments/mean_grad/Size
# train/gradients/batch_normalization/moments/mean_grad/add
# train/gradients/batch_normalization/moments/mean_grad/mod
# train/gradients/batch_normalization/moments/mean_grad/Shape_1
# train/gradients/batch_normalization/moments/mean_grad/range/start
# train/gradients/batch_normalization/moments/mean_grad/range/delta
# train/gradients/batch_normalization/moments/mean_grad/range
# train/gradients/batch_normalization/moments/mean_grad/Fill/value
# train/gradients/batch_normalization/moments/mean_grad/Fill
# train/gradients/batch_normalization/moments/mean_grad/DynamicStitch
# train/gradients/batch_normalization/moments/mean_grad/Maximum/y
# train/gradients/batch_normalization/moments/mean_grad/Maximum
# train/gradients/batch_normalization/moments/mean_grad/floordiv
# train/gradients/batch_normalization/moments/mean_grad/Reshape
# train/gradients/batch_normalization/moments/mean_grad/Tile
# train/gradients/batch_normalization/moments/mean_grad/Shape_2
# train/gradients/batch_normalization/moments/mean_grad/Shape_3
# train/gradients/batch_normalization/moments/mean_grad/Const
# train/gradients/batch_normalization/moments/mean_grad/Prod
# train/gradients/batch_normalization/moments/mean_grad/Const_1
# train/gradients/batch_normalization/moments/mean_grad/Prod_1
# train/gradients/batch_normalization/moments/mean_grad/Maximum_1/y
# train/gradients/batch_normalization/moments/mean_grad/Maximum_1
# train/gradients/batch_normalization/moments/mean_grad/floordiv_1
# train/gradients/batch_normalization/moments/mean_grad/Cast
# train/gradients/batch_normalization/moments/mean_grad/truediv
# train/gradients/AddN_5
# train/gradients/hidden1/BiasAdd_grad/BiasAddGrad
# train/gradients/hidden1/BiasAdd_grad/tuple/group_deps
# train/gradients/hidden1/BiasAdd_grad/tuple/control_dependency
# train/gradients/hidden1/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/hidden1/MatMul_grad/MatMul
# train/gradients/hidden1/MatMul_grad/MatMul_1
# train/gradients/hidden1/MatMul_grad/tuple/group_deps
# train/gradients/hidden1/MatMul_grad/tuple/control_dependency
# train/gradients/hidden1/MatMul_grad/tuple/control_dependency_1
# train/GradientDescent/learning_rate
# train/GradientDescent/update_hidden1/kernel/ApplyGradientDescent
# train/GradientDescent/update_hidden1/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization/beta/ApplyGradientDescent
# train/GradientDescent/update_hidden2/kernel/ApplyGradientDescent
# train/GradientDescent/update_hidden2/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_1/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_1/beta/ApplyGradientDescent
# train/GradientDescent/update_outputs/kernel/ApplyGradientDescent
# train/GradientDescent/update_outputs/bias/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_2/gamma/ApplyGradientDescent
# train/GradientDescent/update_batch_normalization_2/beta/ApplyGradientDescent
# train/GradientDescent
# eval/in_top_k/InTopKV2/k
# eval/in_top_k/InTopKV2
# eval/Cast
# eval/Const
# eval/Mean
# init
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/restore_all

# %%
from tensorflow_graph_in_jupyter import show_graph
show_graph(tf.get_default_graph())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/polymer/0.3.3/platform.js&quot;></script>
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.6071542999629451&quot;).pbtxt = 'node {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;training/input&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_BOOL\n        tensor_shape {\n        }\n        bool_val: false\n      }\n    }\n  }\n}\nnode {\n  name: &quot;training&quot;\n  op: &quot;PlaceholderWithDefault&quot;\n  input: &quot;training/input&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\020\\003\\000\\000,\\001\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -0.07439795136451721\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.07439795136451721\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/max&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/RandomUniform&quot;\n  input: &quot;hidden1/kernel/Initializer/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quo ...

# %%
from functools import partial
tf.reset_default_graph()

n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")
training = tf.placeholder_with_default(False, shape=(), name="training")

hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1")
bn1 = tf.layers.batch_normalization(hidden1, training=training, momentum=0.9)
bn1_act = tf.nn.elu(bn1)

hidden2 = tf.layers.dense(bn1_act, n_hidden2, name="hidden2")
bn2 = tf.layers.batch_normalization(hidden2, training=training, momentum=0.9)
bn2_act = tf.nn.elu(bn2)

logits_before_bn = tf.layers.dense(bn2_act, n_outputs, name="outputs")
logits = tf.layers.batch_normalization(logits_before_bn, training=training, momentum=0.9)
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

n_epochs = 5
batch_size = 200

extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run([training_op, extra_update_ops], feed_dict={training: True, X: X_batch, y: y_batch})
        accuracy_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Validation accuracy:", accuracy_val)

    save_path = saver.save(sess, "./mnist_nn_ch11.ckpt")
# Out:
# 0 Validation accuracy: 0.8826
# 1 Validation accuracy: 0.9082
# 2 Validation accuracy: 0.9194
# 3 Validation accuracy: 0.928
# 4 Validation accuracy: 0.935

# %%
with tf.Session() as sess:
    saver.restore(sess, "./mnist_nn_ch11.ckpt")

    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        accuracy_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Validation accuracy:", accuracy_val)

    save_path = saver.save(sess, "./mnist_nn_ch11_2.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from ./mnist_nn_ch11.ckpt
# 0 Validation accuracy: 0.941
# 1 Validation accuracy: 0.9468
# 2 Validation accuracy: 0.95
# 3 Validation accuracy: 0.9556
# 4 Validation accuracy: 0.9576

# %%
tf.reset_default_graph()

#set the constants
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 50
n_hidden3 = 50
n_hidden4 = 50
n_outputs = 10

learning_rate = 0.01

#placeholders for inputs and outputs
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

#build the actual nn
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, activation=tf.nn.relu, name='hidden1')
    hidden2 = tf.layers.dense(hidden1, n_hidden2, activation=tf.nn.relu, name='hidden2')
    hidden3 = tf.layers.dense(hidden2, n_hidden3, activation=tf.nn.relu, name='hidden3')
    hidden4 = tf.layers.dense(hidden3, n_hidden4, activation=tf.nn.relu, name="hidden4")
    logits = tf.layers.dense(hidden4, n_outputs, name='outputs')

#apply an error calculation function to the logits (cross-entropy)
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=y)
    loss = tf.reduce_mean(xentropy, name='loss')

#train the model
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
#evaluate the accuracy of the model
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
n_epochs = 5
batch_size = 200
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
saver = tf.train.Saver() 

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run([training_op, extra_update_ops], feed_dict={X:X_batch, y:y_batch})
        accuracy_val = accuracy.eval(feed_dict={X:X_valid, y:y_valid})
        print(epoch, "accuracy: ", accuracy_val)
    saver.save(sess, './mnist_nn_5.ckpt')
# Out:
# 0 accuracy:  0.6284
# 1 accuracy:  0.8392
# 2 accuracy:  0.8932
# 3 accuracy:  0.9096
# 4 accuracy:  0.9212

# %%
tf.reset_default_graph()

n_hidden4 = 20
n_outputs = 10
learning_rate = 0.01

saver = tf.train.import_meta_graph('./mnist_nn_5.ckpt.meta')

X = tf.get_default_graph().get_tensor_by_name('X:0')
y = tf.get_default_graph().get_tensor_by_name('y:0')

hidden3 = tf.get_default_graph().get_tensor_by_name('dnn/hidden3/Relu:0')

new_hidden4 = tf.layers.dense(hidden3, n_hidden4, activation=tf.nn.relu, name='new_hidden4')
new_logits = tf.layers.dense(new_hidden4, n_outputs, name='new_outputs')

with tf.name_scope('new_loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=new_logits, labels=y)
    loss = tf.reduce_mean(xentropy, name='new_loss')

with tf.name_scope('new_eval'):
    correct = tf.nn.in_top_k(new_logits, y, 1)
    accucacy = tf.reduce_mean(tf.cast(correct, tf.float32), name='accuracy')

with tf.name_scope('new_train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)


init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
tf.reset_default_graph()

n_inputs = 28 * 28  # MNIST
n_hidden1 = 300 # reused
n_hidden2 = 50  # reused
n_hidden3 = 50  # reused
n_hidden4 = 20  # new!
n_outputs = 10  # new!

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, activation=tf.nn.relu, name="hidden1")       # reused
    hidden2 = tf.layers.dense(hidden1, n_hidden2, activation=tf.nn.relu, name="hidden2") # reused
    hidden3 = tf.layers.dense(hidden2, n_hidden3, activation=tf.nn.relu, name="hidden3") # reused
    hidden4 = tf.layers.dense(hidden3, n_hidden4, activation=tf.nn.relu, name="hidden4") # new!
    logits = tf.layers.dense(hidden4, n_outputs, name="outputs")                         # new!

with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
reuse_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='hidden[123]')
restore_saver = tf.train.Saver(reuse_vars)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    init.run()
    restore_saver.restore(sess, './mnist_nn_5.ckpt')
    for epoch in range(n_epochs):                                            # not shown in the book
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size): # not shown
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})        # not shown
        accuracy_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})     # not shown
        print(epoch, "Validation accuracy:", accuracy_val)
# Out:
# INFO:tensorflow:Restoring parameters from ./mnist_nn_5.ckpt
# 0 Validation accuracy: 0.8294
# 1 Validation accuracy: 0.8912
# 2 Validation accuracy: 0.9064
# 3 Validation accuracy: 0.9182
# 4 Validation accuracy: 0.9244
